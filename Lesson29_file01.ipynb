# %% [markdown]
# **Рішення завдання №1**

# %% [markdown]
# За умовою задачі маємо наступний інтервальний статичний розподіл(Аі-1/Аі, Ni),рівень значущості а=0.01.Знайдемо значення серединих часткових інтервалів Хі за формулою: Xi=((Ai-1)+Ai)/2

# %% [markdown]
# |Ai-1/Ai|0-24|24-48|48-72|72-96|96-120|120-144|144-168|168-192|192-216|
# |:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|:---:|
# |Ni|1|2|4|6|12|16|6|2|1|
# |Xi|12|36|60|84|108|132|156|180|204|

# %% [markdown]
# Розрахуємо N=sum(Ni)=50.

# %% [markdown]
# Розрахуємо середній показник ,близький до математичного сподівання:Х1 за наступною формулою: X1=(1/n)*sum(Xi*Ni)=114.72

# %% [markdown]
# Розрахуємо дисперсію D1 за формулою: D1=(1/n)*sum((Xi**2)*Ni)-X1**2=1452.44

# %% [markdown]
#  Розрахуємо стандартне відхилення Sd за наступною формулою: Sd=D1**0.5

# %%
D1=1452.44
Sd=D1**0.5
Sd
# Out:
# 38.11089083188689

# %% [markdown]
# |i|Zi-1 : Zi|Ф(Zi-1)|Ф(Zi)|Pi=Ф(Zi)-Ф(Zi-1)|Ni1=N*Pi|
# |:---:|:---:|:---:|:---:|:---:|:---:|
# |1|-s:-2.38|-0.5|-0.4913|0.0087|0.435=1|
# |2|-2.38:-1.75|-0.4913|-0.4599|0.0314|1.57=2|
# |3|-1.75:-1.12|-0.4599|-0.3686|0.0913|4.565=5|
# |4|-1.12:-0.49|-0.3686|-0.1879|0.1807|9.035=10|
# |5|-0.49:0.14|-0.1879|0.0557|0.2436|12.18=12|
# |6|0.14:0.77|0.5557|0.2794|0.2237|11.185=11|
# |7|0.77:1.40|0.2794|0.4192|0.1398|6.99=7|
# |8|1.40:2.02|0.4192|0.4783|0.0591|2.955=3|
# |9|2.02: s|0.4783|0.5|0.0217|1.085=1|

# %% [markdown]
# |Ni|Ni1|Ni-Ni1|(Ni-Ni1)**2|((Ni-Ni1)**2)/Ni1|
# |:---:|:---:|:---:|:---:|:---:|
# |1|1|0|0|0|0.435=1|
# |2|2|0|0|0|
# |4|5|-1|1|0.2|
# |6|10|-4|16|1.6|
# |12|12|0|0|0|
# |16|11|5|25|2.27|
# |6|7|-1|1|0.14|
# |2|3|-1|1|0.33|
# |1|1|0|0|0|

# %% [markdown]
# Знайдемо Kemp за наступною формулою: Kemp=sum(((Ni-Ni1)**2/Ni1)= 4.54.
# За таблицею знаходимо критерій узгодження Пірсона при а=0.01, r=m-s-1, де m=9(кількість інтервалів інтервального розподілу статистичної імовірності), n=2(число параметрів теоретичного розподілу): Kkr=16.8.

# %% [markdown]
# Оскільки Kkr> Kemp приймаємо гіпотезу і погоджуємось, що розподіл близький до нормального.
